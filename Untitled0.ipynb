# %%
# Circle PIE * r * r

print ('เครื่องมือหาพื้นที่วงกลม')
print ()

r = int(input('ใส่รัศมีของวงกลม = '))
PIE = (22/7)
result = int(PIE * r * r)

print ()
print ('พื้นที่วงกลมมีค่า = %s cm^2' %result)
print ()
print ('***********************************************************************************')
print ()

# 3D Box W * L * H

print ('เครื่องมือหาปริมาตรลูกบาสก์')
print ()

W = int(input('ใส่ความกว้างของลูกบาสก์ = '))
L = int(input('ใส่ความยาวของลูกบาสก์  = '))
H = int(input('ใส่ความสูงของลูกบาสก์   = '))
result = int(W * L * H)

print ()
print ('ปริมาตรของลูกบาสก์มีค่า = %s cm^3' %result)
print ()
print ()
print ()

print ('ได้รึเปล่าครับพี่ ผมลองแปลงจากโค้ดพื้นที่สามเหลี่ยมของพี่ดู')
print ('เป็นการเขียนโค้ดครั้งแรก สนุกมากเลยครับ5555')
print ('ขอบคุณพี่ๆทุกคนที่เข้ามาสละเวลามาสอนมากๆนะครับ')
# Out:
# เครื่องมือหาพื้นที่วงกลม
#
# ใส่รัศมีของวงกลม = 7
#
# พื้นที่วงกลมมีค่า = 154 cm^2
#
# ***********************************************************************************
#
# เครื่องมือหาปริมาตรลูกบาสก์
#
# ใส่ความกว้างของลูกบาสก์ = 5
# ใส่ความยาวของลูกบาสก์  = 5
# ใส่ความสูงของลูกบาสก์   = 5
#
# ปริมาตรของลูกบาสก์มีค่า = 125 cm^3
#
#
#
# ได้รึเปล่าครับพี่ ผมลองแปลงจากโค้ดพื้นที่สามเหลี่ยมของพี่ดู
# เป็นการเขียนโค้ดครั้งแรก สนุกมากเลยครับ5555
# ขอบคุณพี่ๆทุกคนที่เข้ามาสละเวลามาสอนมากๆนะครับ
